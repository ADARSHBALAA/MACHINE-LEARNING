# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("./walmart-sales-dataset-of-45stores.csv ",parse_dates=['Date'])

# %%
data
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.sort_values(by='Date',inplace=True)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data['year']=data.Date.dt.year
data['month']=data.Date.dt.month
data['day']=data.Date.dt.day
data['weekday']=data.Date.dt.weekday

# %%
data.drop(columns=['Date'],inplace=True)

# %%
data
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         5     283178.12             0        71.10       2.603  212.226946
# 1        15     566945.95             0        59.69       2.840  132.756800
# 2        42     481523.93             0        86.01       3.001  126.234600
# 3        33     224294.39             0        91.45       3.001  126.234600
# 4        36     422169.47             0        74.66       2.567  210.440443
# ...     ...           ...           ...          ...         ...         ...
# 6430     41    1409544.97             0        39.38       3.760  199.053937
# 6431     16     491817.19             0        43.26       3.760  199.053937
# 6432     10    1713889.11             0        76.03       4.468  131.108333
# 6433     25     697317.41             0        43.74       4.000  216.115057
# 6434      2    1900745.13             0        60.97       3.601  223.015426
#
# ...

# %%
data.weekday.replace({0:'sunday',1:'monday',2:'tuesday',3:'wednesday',4:'thusday',5:'friday',6:'saturday'},inplace=True)

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment         year        month          day
# count  6435.000000   6435.000000  6435.000000  6435.000000  6435.000000
# mean    171.578394      7.999151  2010.965035     6.475524    15.650350
# std      39.356712      1.875885     0.797019     3.321797     8.753908
# ...

# %%
data.isnull().sum()
# Out:
# Store           0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# year            0
# month           0
# day             0
# weekday         0
# dtype: int64

# %%
data.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      5     283178.12             0        71.10       2.603  212.226946
# 1     15     566945.95             0        59.69       2.840  132.756800
# 2     42     481523.93             0        86.01       3.001  126.234600
# 3     33     224294.39             0        91.45       3.001  126.234600
# 4     36     422169.47             0        74.66       2.567  210.440443
#
#    Unemployment  year  month  day   weekday
# 0         6.768  2010      1   10  saturday
# 1         8.067  2010      1   10  saturday
# 2         9.003  2010      1   10  saturday
# 3         9.265  2010      1   10  saturday
# 4         8.476  2010      1   10  saturday

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,3,1)
sns.histplot(data=data,kde=True,x='Weekly_Sales',color='red')

plt.subplot(2,3,2)
sns.histplot(data=data,kde=True,x='Temperature',color='green')


plt.subplot(2,3,3)
sns.histplot(data=data,kde=True,x='Fuel_Price',color='purple')

plt.subplot(2,3,4)
sns.histplot(data=data,kde=True,x='CPI',color='yellow')

plt.subplot(2,3,5)
sns.histplot(data=data,kde=True,x='Unemployment',color='blue')
# Out:
# <Axes: xlabel='Unemployment', ylabel='Count'>

# %%
data.columns
# Out:
# Index(['Store', 'Weekly_Sales', 'Holiday_Flag', 'Temperature', 'Fuel_Price',
#        'CPI', 'Unemployment', 'year', 'month', 'day', 'weekday'],
#       dtype='object')

# %%
col_list=[ 'Weekly_Sales', 'Temperature', 'Fuel_Price',
       'CPI', 'Unemployment']

# %%
for i in col_list:
    sns.boxplot(y=data[i],data=data,color='magenta')
    plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,3,1)
sns.boxplot(data=data,x='Weekly_Sales',color='red')

plt.subplot(2,3,2)
sns.boxplot(data=data,x='Temperature',color='cyan')


plt.subplot(2,3,3)
sns.boxplot(data=data,x='Fuel_Price',color='purple')

plt.subplot(2,3,4)
sns.boxplot(data=data,x='CPI',color='yellow')

plt.subplot(2,3,5)
sns.boxplot(data=data,x='Unemployment',color='blue')
# Out:
# <Axes: xlabel='Unemployment'>

# %%
plt.figure(figsize=(16,5))
plt.xlabel('Year')
plt.ylabel('Weekly_Sales')
plt.title('veriation in Weekly_Sales over years')
plt.axhline(y=data.year.mean(),color='r')
sns.lineplot(data=data,x='year',y='Weekly_Sales')
plt.show()

# %%
data
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         5     283178.12             0        71.10       2.603  212.226946
# 1        15     566945.95             0        59.69       2.840  132.756800
# 2        42     481523.93             0        86.01       3.001  126.234600
# 3        33     224294.39             0        91.45       3.001  126.234600
# 4        36     422169.47             0        74.66       2.567  210.440443
# ...     ...           ...           ...          ...         ...         ...
# 6430     41    1409544.97             0        39.38       3.760  199.053937
# 6431     16     491817.19             0        43.26       3.760  199.053937
# 6432     10    1713889.11             0        76.03       4.468  131.108333
# 6433     25     697317.41             0        43.74       4.000  216.115057
# 6434      2    1900745.13             0        60.97       3.601  223.015426
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.regplot(data=data,x='Weekly_Sales',y='Temperature',color='coral')

plt.subplot(2,2,2)
sns.regplot(data=data,x='Fuel_Price',y='Temperature',color='lime')

plt.subplot(2,2,3)
sns.regplot(data=data,x='Fuel_Price',y='Weekly_Sales',color='violet')

plt.subplot(2,2,4)
sns.regplot(data=data,x='Unemployment',y='CPI',color='teal')
# Out:
# <Axes: xlabel='Unemployment', ylabel='CPI'>

# %%
data.hist(figsize=(20,10),color='cyan');

# %%
sns.boxplot(data=data,x='weekday',y='Weekly_Sales',hue='year')
plt.show()

# %% [markdown]
# inference
# from the data set ,the overall sales in thusday is more than rest of all
# and thers is no huge sales differance occured, but in 2010 and 2011 a huge differance measured

# %%
year_2010=data.query("year==2010")

# %%
year_2011=data.query("year==2011")

# %%
year_2012=data.query("year==2012")

# %%
plt.figure(figsize=(14,21))
plt.subplot(4,3,1)
sns.barplot(data=year_2010,x='month',y='Weekly_Sales',color='red')
plt.title('year 2010 analysis')
plt.xticks(rotation=55)


plt.subplot(4,3,2)
sns.barplot(data=year_2011,x='month',y='Weekly_Sales',color='red')
plt.title('year 2011 Weekly_Sales analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,3)
sns.barplot(data=year_2012,x='month',y='Weekly_Sales',color='red')
plt.title('year 2012 Weekly_Sales analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,4)
sns.barplot(data=year_2010,x='month',y='Unemployment',color='cyan')
plt.title('year 2010 Weekly_Sales analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,5)
sns.barplot(data=year_2011,x='month',y='Unemployment',color='cyan')
plt.title('year 2011 Unemployment analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,6)
sns.barplot(data=year_2012,x='month',y='Unemployment',color='cyan')
plt.title('year 2012 Unemployment analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,7)
sns.barplot(data=year_2010,x='month',y='Temperature',color='purple')
plt.title('year 2010 Temperature analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,8)
sns.barplot(data=year_2011,x='month',y='Temperature',color='purple')
plt.title('year 2011 Temperature analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,9)
sns.barplot(data=year_2012,x='month',y='Temperature',color='purple')
plt.title('year 2012 Temperature analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,10)
sns.barplot(data=year_2010,x='month',y='Fuel_Price',color='orange')
plt.title('year 2010 Fuel_Price analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,11)
sns.barplot(data=year_2011,x='month',y='Fuel_Price',color='orange')
plt.title('year 2011 Fuel_Price analysis')
plt.xticks(rotation=55)

plt.subplot(4,3,12)
sns.barplot(data=year_2012,x='month',y='Fuel_Price',color='orange')
plt.title('year 2012 Fuel_Price analysis')
plt.xticks(rotation=55)
plt.show()

# %%
data
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         5     283178.12             0        71.10       2.603  212.226946
# 1        15     566945.95             0        59.69       2.840  132.756800
# 2        42     481523.93             0        86.01       3.001  126.234600
# 3        33     224294.39             0        91.45       3.001  126.234600
# 4        36     422169.47             0        74.66       2.567  210.440443
# ...     ...           ...           ...          ...         ...         ...
# 6430     41    1409544.97             0        39.38       3.760  199.053937
# 6431     16     491817.19             0        43.26       3.760  199.053937
# 6432     10    1713889.11             0        76.03       4.468  131.108333
# 6433     25     697317.41             0        43.74       4.000  216.115057
# 6434      2    1900745.13             0        60.97       3.601  223.015426
#
# ...

# %%
plt.figure(figsize=(10,10))
heat_map=data.corr()
sns.heatmap(heat_map,vmin=-1,vmax=1,annot=True, linewidth=1)
plt.show()
