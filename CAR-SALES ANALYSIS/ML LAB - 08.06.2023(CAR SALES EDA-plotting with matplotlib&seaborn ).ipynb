# %% [markdown]
# # <CENTER>CAR SALES - EXPORATORY DATA ANALYSIS

# %% [markdown]
# ###       PLOTTING WITH MATPLOTLIB AND SEABORN

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("./Car_sales (1).csv",parse_dates=['Latest_Launch'])

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.sort_values(by='Latest_Launch',inplace=True)

# %%
data['Year']=data.Latest_Launch.dt.year
data['Month']= data.Latest_Launch.dt.month
data['Day']=data.Latest_Launch.dt.day

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 90 to 139
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
data.head()
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 90       Mercury  Mountaineer              27.609               20.430
# 91       Mercury     Villager              20.380               14.795
# 110   Oldsmobile        Alero              80.255                  NaN
# 131       Saturn           SW               5.223               10.790
# 96    Mercedes-B          SLK               7.998                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 90           Car               27.56          4.0       210.0      111.6
# 91           Car               22.51          3.3       170.0      112.2
# 110    Passenger               18.27          2.4       150.0      107.0
# 131    Passenger               14.29          1.9       124.0      102.4
# 96     Passenger               38.90          2.3       190.0       94.5
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.describe().T
# Out:
#                      count         mean        std          min          25%  \
# Sales_in_thousands   157.0    52.998076  68.029422     0.110000    14.114000
# __year_resale_value  121.0    18.072975  11.453384     5.160000    11.260000
# Price_in_thousands   155.0    27.390755  14.351653     9.235000    18.017500
# Engine_size          156.0     3.060897   1.044653     1.000000     2.300000
# Horsepower           156.0   185.948718  56.700321    55.000000   149.500000
# Wheelbase            156.0   107.487179   7.641303    92.600000   103.000000
# Width                156.0    71.150000   3.451872    62.600000    68.400000
# Length               156.0   187.343590  13.431754   149.400000   177.575000
# Curb_weight          155.0     3.378026   0.630502     1.895000     2.971000
# Fuel_capacity        156.0    17.951923   3.887921    10.300000    15.800000
# Fuel_efficiency      154.0    23.844156   4.282706    15.000000    21.000000
# ...

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# Year                    0.000000
# Month                   0.000000
# Day                     0.000000
# dtype: float64

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().mean()*100
# Out:
# Manufacturer           0.0
# Model                  0.0
# Sales_in_thousands     0.0
# __year_resale_value    0.0
# Vehicle_type           0.0
# Price_in_thousands     0.0
# Engine_size            0.0
# Horsepower             0.0
# Wheelbase              0.0
# Width                  0.0
# Length                 0.0
# Curb_weight            0.0
# Fuel_capacity          0.0
# Fuel_efficiency        0.0
# Latest_Launch          0.0
# Power_perf_factor      0.0
# Year                   0.0
# Month                  0.0
# Day                    0.0
# dtype: float64

# %%
data.head()
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 90       Mercury  Mountaineer              27.609               20.430
# 91       Mercury     Villager              20.380               14.795
# 131       Saturn           SW               5.223               10.790
# 145   Volkswagen         Golf               9.761               11.425
# 137       Toyota        Camry             247.994               13.245
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 90           Car              27.560          4.0       210.0      111.6
# 91           Car              22.510          3.3       170.0      112.2
# 131    Passenger              14.290          1.9       124.0      102.4
# 145    Passenger              14.900          2.0       115.0       98.9
# 137    Passenger              17.518          2.2       133.0      105.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# ### EXPLORATRY DATA ANALYSIS USING - MATPLOTLIB  AND  SEABORN

# %% [markdown]
# #### HIST PLOT

# %%
sns.histplot(data=data,x='Sales_in_thousands')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### box plot

# %%
sns.boxplot(data=data,x='Sales_in_thousands')

plt.show()

# %%
sns.boxplot(data=data,y='Sales_in_thousands')
plt.show()

# %% [markdown]
# ### Kernel Density Estimation Plot (KDE PLOT)

# %%
sns.kdeplot(data=data,x='Sales_in_thousands')
plt.show()

# %% [markdown]
# # SUB PLOTS

# %% [markdown]
# ### HIST PLOT

# %%
sns.histplot(data=data)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=35)
sns.histplot(data=data)
plt.show()

# %% [markdown]
# ### BOX PLOT

# %%
sns.boxplot(data=data)
plt.show()

# %%
plt.figure(figsize=(16,8) )
plt.xticks(rotation=45)
sns.boxplot(data=data)
plt.show()

# %%
data.rename(columns={'__year_resale_value':'resale_value'} , inplace=True)

# %% [markdown]
# ### KDE PLOT

# %%
sns.kdeplot(data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.xticks(rotation=62)
sns.kdeplot(data=data)
plt.show()

# %% [markdown]
# # For loop to plot subplots

# %% [markdown]
# ### HIST PLOT

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        sns.histplot(x=data[i])
        plt.show()

# %% [markdown]
# ### BOX PLOT

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        sns.boxplot(y=data[i])
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 for i in data.columns:
#       2     if data[i].dtypes !='object':
# ----> 3         sns.boxplot(y=data[i])
#       4         plt.show()
#
# File ~\ARUN\anaconda\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
# ...

# %% [markdown]
# ### KDE PLOT

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        sns.kdeplot(x=data[i])
        plt.show()

# %% [markdown]
# # Subplots in matplotlib

# %% [markdown]
# ### hist plot

# %%
plt.figure(figsize=(16,8))
plt.subplot(4,4,1)
sns.histplot(data=data,x='Sales_in_thousands')

plt.subplot(4,4,2)
sns.histplot(data=data,x='resale_value')

plt.subplot(4,4,3)
sns.histplot(data=data,x='Price_in_thousands')

plt.subplot(4,4,4)
sns.histplot(data=data,x='Engine_size')

plt.subplot(4,4,5)
sns.histplot(data=data,x='Horsepower')

plt.subplot(4,4,6)
sns.histplot(data=data,x='Wheelbase')

plt.subplot(4,4,7)
sns.histplot(data=data,x='Width')

plt.subplot(4,4,8)
sns.histplot(data=data,x='Length')

plt.subplot(4,4,9)
sns.histplot(data=data,x='Curb_weight')

plt.subplot(4,4,10)
sns.histplot(data=data,x='Fuel_capacity')


plt.subplot(4,4,11)
sns.histplot(data=data,x='Fuel_efficiency')


plt.subplot(4,4,12)
sns.histplot(data=data,x='Latest_Launch')


plt.subplot(4,4,13)
sns.histplot(data=data,x='Power_perf_factor')


plt.subplot(4,4,14)
sns.histplot(data=data,x='Year')


plt.subplot(4,4,15)
sns.histplot(data=data,x='Month')


plt.subplot(4,4,16)
sns.histplot(data=data,x='Day')

# %%
plt.figure(figsize=(16,8))
plt.subplot(3,2,1)
sns.boxplot(data=data,x='Sales_in_thousands')

plt.subplot(3,2,2)
sns.boxplot(data=data,x='resale_value')

plt.subplot(3,2,3)
sns.boxplot(data=data,x='Price_in_thousands')

plt.subplot(3,2,4)
sns.boxplot(data=data,x='Engine_size')

plt.subplot(3,2,5)
sns.boxplot(data=data,x='Horsepower')

plt.subplot(3,2,6)
sns.boxplot(data=data,x='Wheelbase')

# %% [markdown]
# ### kde plot

# %%
plt.figure(figsize=(16,8))
plt.subplot(3,2,1)
sns.kdeplot(data=data,x='Sales_in_thousands')

plt.subplot(3,2,2)
sns.kdeplot(data=data,x='resale_value')

plt.subplot(3,2,3)
sns.kdeplot(data=data,x='Price_in_thousands')

plt.subplot(3,2,4)
sns.kdeplot(data=data,x='Engine_size')

plt.subplot(3,2,5)
sns.kdeplot(data=data,x='Horsepower')

plt.subplot(3,2,6)
sns.kdeplot(data=data,x='Wheelbase')

# %% [markdown]
# ### count plot

# %%
plt.figure(figsize=(16,8))
plt.subplot(3,2,1)
sns.countplot(data=data,x='Sales_in_thousands')

plt.subplot(3,2,2)
sns.countplot(data=data,x='resale_value')

plt.subplot(3,2,3)
sns.countplot(data=data,x='Price_in_thousands')

plt.subplot(3,2,4)
sns.countplot(data=data,x='Engine_size')

plt.subplot(3,2,5)
sns.countplot(data=data,x='Horsepower')

plt.subplot(3,2,6)
sns.countplot(data=data,x='Wheelbase')

# %% [markdown]
# ## Subplots using enumerate

# %% [markdown]
# #### Let's create list in which there is only the columns which we are going to plot

# %%
features=[]

# %%
for i in data.columns:
     if data[i].dtypes != 'object':
        features.append(i)

# %%
list(enumerate(features))

# %%
features

# %%
 plt.figure(figsize=(20,10))
for i in enumerate(features):
     plt.subplot(4,4,i[0]+1)
     sns.histplot(data=data, x=i[1], color='red')

# %% [markdown]
# ### kde plot

# %%
plt.figure(figsize=(20,10))
for i in enumerate(features):
     plt.subplot(4,4,i[0]+1)
     sns.kdeplot(data=data, x=i[1], color='red')

# %%
plt.figure(figsize=(13,10))
for i in enumerate(features):
    plt.subplot(4,4,i[0]+1)
    sns.boxplot(data=data, y=i[1], color='red')

# %% [markdown]
# # Line charts

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Year Resale Value')
plt.ylabel('Price')
plt.title('Resale Value and Price graph')
sns.lineplot(data=data,x='resale_value', y='Price_in_thousands')
plt.show()

# %%
sns.lineplot(data=data,x='Engine_size',y='Horsepower')
plt.show()

# %% [markdown]
# # Count plot

# %%
sns.countplot(data=data,x='Horsepower')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.xticks(rotation = 45)
sns.countplot(data=data,x='Manufacturer')
plt.show()

# %% [markdown]
# ### Area chart

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=60)
plt.stackplot(data.Manufacturer,data.resale_value)
plt.show()

# %%
data.head(2)

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=60)
plt.stackplot(data.Year,data.resale_value)
plt.show()
