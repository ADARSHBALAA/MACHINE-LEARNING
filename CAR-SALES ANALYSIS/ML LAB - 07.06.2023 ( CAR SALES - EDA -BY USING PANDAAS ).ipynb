# %% [markdown]
# # <center>CAR SALES

# %% [markdown]
# # <center>Exploratory data analysis--USING PANDAS

# %% [markdown]
# ![images.jpg](attachment:images.jpg)

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("./Car_sales (1).csv")

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
data.rename(columns={'__year_resale_value':'resale_value'} , inplace=True)

# %% [markdown]
# # HISTOGRAM

# %%
data.Sales_in_thousands.plot.hist();

# %%
data.Wheelbase.plot.hist(cmap='rainbow')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.Length.plot.hist(figsize=(6,3),cmap="Blues_r");

# %% [markdown]
# ### HISTOGRAM SUB PLOTING

# %%
data.plot.hist(figsize=(8,16),subplots=True);

# %%
data.hist(figsize=(20,10),color='red');

# %% [markdown]
# ### BOX SUB PLOTING

# %%
data.plot.box(figsize=(20,4),subplots=True);

# %% [markdown]
# ### KDE SUB PLOTING

# %%
data.plot.kde(figsize=(5,10),subplots=True);

# %% [markdown]
# ### MULTI VERIANT PLOTTING

# %% [markdown]
# ##### LINE CHART

# %%
data.sort_values(by='Manufacturer').plot.line('Manufacturer','Sales_in_thousands');

# %%
data.sort_values(by='Vehicle_type').plot.line('Vehicle_type','Price_in_thousands',figsize=(8,3),cmap='turbo_r');

# %% [markdown]
# #### BAR PLOT

# %%
data.Fuel_efficiency.value_counts().plot.bar();

# %%
data.Engine_size.value_counts().plot.bar(figsize=(6,3),cmap='inferno');

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(12,4),cmap='turbo_r');

# %% [markdown]
# ### AREA CHART

# %%
data.plot.area('Manufacturer','resale_value');

# %%
data.plot.area('Model','resale_value',figsize=(12,3),cmap='Pastel2');

# %% [markdown]
# ### HORIZONTAL BAR CHART

# %%
data.sort_values(by='Manufacturer')[:10].plot.barh('Manufacturer','Power_perf_factor',figsize=(12,4),cmap='Pastel2')
# Out:
# <Axes: ylabel='Manufacturer'>

# %%
data.sort_values(by='Model')[:20].plot.barh('Model','Wheelbase',figsize=(15,8),cmap='inferno')
# Out:
# <Axes: ylabel='Model'>

# %% [markdown]
# ### SCATTER PLOT

# %%
data.sort_values(by='Power_perf_factor')[:100].plot.scatter('Power_perf_factor','Fuel_efficiency',figsize=(4,4))
# Out:
# <Axes: xlabel='Power_perf_factor', ylabel='Fuel_efficiency'>

# %%
data.sort_values(by='Sales_in_thousands')[:100].plot.scatter('Engine_size','Horsepower',figsize=(4,4));

# %% [markdown]
# ### PIE PLOT

# %%
data.sort_values(by='Engine_size',ascending=False)[:25].Engine_size.plot.pie();

# %%
data.sort_values(by='Price_in_thousands',ascending=False)[:15].Price_in_thousands.plot.pie();

# %%
data.Manufacturer.value_counts()[:10].plot.pie(autopct='%1.2f%%');
