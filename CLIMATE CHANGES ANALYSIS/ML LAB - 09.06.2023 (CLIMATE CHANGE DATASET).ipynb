# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("./climate_change_data.csv",parse_dates=['Date'])

# %%
data
# Out:
#                               Date           Location                Country  \
# 0    2000-01-01 00:00:00.000000000    New Williamtown                 Latvia
# 1    2000-01-01 20:09:43.258325832       North Rachel           South Africa
# 2    2000-01-02 16:19:26.516651665   West Williamland          French Guiana
# 3    2000-01-03 12:29:09.774977497        South David                Vietnam
# 4    2000-01-04 08:38:53.033303330     New Scottburgh                Moldova
# ...                            ...                ...                    ...
# 9995 2022-12-27 15:21:06.966696576   South Elaineberg                 Bhutan
# 9996 2022-12-28 11:30:50.225022464       Leblancville                  Congo
# 9997 2022-12-29 07:40:33.483348224     West Stephanie              Argentina
# 9998 2022-12-30 03:50:16.741674112        Port Steven                Albania
# 9999 2022-12-31 00:00:00.000000000  West Anthonyburgh  Sao Tome and Principe
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  datetime64[ns]
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 703.2+ KB

# %%
data.sort_values(by='Date',inplace=True)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data['Year']=data.Date.dt.year
data['Month']=data.Date.dt.month
data['Day']=data.Date.dt.day

# %%
data
# Out:
#                               Date           Location                Country  \
# 0    2000-01-01 00:00:00.000000000    New Williamtown                 Latvia
# 1    2000-01-01 20:09:43.258325832       North Rachel           South Africa
# 2    2000-01-02 16:19:26.516651665   West Williamland          French Guiana
# 3    2000-01-03 12:29:09.774977497        South David                Vietnam
# 4    2000-01-04 08:38:53.033303330     New Scottburgh                Moldova
# ...                            ...                ...                    ...
# 9995 2022-12-27 15:21:06.966696576   South Elaineberg                 Bhutan
# 9996 2022-12-28 11:30:50.225022464       Leblancville                  Congo
# 9997 2022-12-29 07:40:33.483348224     West Stephanie              Argentina
# 9998 2022-12-30 03:50:16.741674112        Port Steven                Albania
# 9999 2022-12-31 00:00:00.000000000  West Anthonyburgh  Sao Tome and Principe
#
# ...

# %%
data.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  datetime64[ns]
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
#  9   Year            10000 non-null  int64
#  10  Month           10000 non-null  int64
#  11  Day             10000 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(2)
# memory usage: 937.6+ KB

# %%
data.drop(columns=['Date'],inplace=True)

# %%
data
# Out:
#                Location                Country  Temperature  CO2 Emissions  \
# 0       New Williamtown                 Latvia    10.688986     403.118903
# 1          North Rachel           South Africa    13.814430     396.663499
# 2      West Williamland          French Guiana    27.323718     451.553155
# 3           South David                Vietnam    12.309581     422.404983
# 4        New Scottburgh                Moldova    13.210885     410.472999
# ...                 ...                    ...          ...            ...
# 9995   South Elaineberg                 Bhutan    15.020523     391.379537
# 9996       Leblancville                  Congo    16.772451     346.921190
# 9997     West Stephanie              Argentina    22.370025     466.042136
# 9998        Port Steven                Albania    19.430853     337.899776
# 9999  West Anthonyburgh  Sao Tome and Principe    12.661928     381.172746
#
# ...

# %% [markdown]
# ##### find numeric columns

# %%
features=[]
for i in data.columns:
    if data[i].dtypes != 'object':
        features.append(i)

# %%
list(enumerate(features))
# Out:
# [(0, 'Temperature'),
#  (1, 'CO2 Emissions'),
#  (2, 'Sea Level Rise'),
#  (3, 'Precipitation'),
#  (4, 'Humidity'),
#  (5, 'Wind Speed'),
#  (6, 'Year'),
#  (7, 'Month'),
#  (8, 'Day')]

# %% [markdown]
# ##### maximum Temperature varified in data

# %%
data.Temperature.nlargest()
# Out:
# 5601    33.976956
# 9228    33.907976
# 4370    32.745123
# 2839    32.403159
# 2224    31.455420
# Name: Temperature, dtype: float64

# %% [markdown]
# ##### which country occured maximum Temperature

# %%
Max_temp = data.nlargest(10, 'Temperature')

# %%
Max_temp
# Out:
#                Location                 Country  Temperature  CO2 Emissions  \
# 5601        Bradleyport                   Niger    33.976956     370.009529
# 9228        East Lauren                 Reunion    33.907976     330.584735
# 4370       Kellychester  Libyan Arab Jamahiriya    32.745123     401.100887
# 2839      Lake Johnbury                  Malawi    32.403159     352.800570
# 2224       Perezborough                 Uruguay    31.455420     469.597143
# 6347       Espinozaport                 Nigeria    31.221108     324.770917
# 5949     West Erikaland                Thailand    31.092676     382.500307
# 3408      South Anthony                Kiribati    30.866866     427.782659
# 7667   Lake Robertmouth              San Marino    30.844262     398.971608
# 1654  Lake Michelleview       Brunei Darussalam    30.816299     374.079413
#
#       Sea Level Rise  Precipitation   Humidity  Wind Speed  Year  Month  Day
# ...

# %% [markdown]
# ##### top 10 on data, country occured maximum Humidity

# %%
Max_Humidity_10 = data.nlargest(10, 'Humidity')

# %%
Max_Humidity_10
# Out:
#             Location         Country  Temperature  CO2 Emissions  \
# 2869     West Ashley         Finland    17.711044     486.118907
# 1953    Martinezbury          Serbia    13.688881     423.866821
# 8956   West Lukestad  Cayman Islands    15.470411     411.102018
# 1342     East Dustin            Togo    17.603016     337.818248
# 5679    Meredithberg         Romania    13.050971     413.714771
# 9328   South Natalie         Ukraine    16.331520     413.909722
# 1698  East Ericatown         Jamaica    13.090675     451.191766
# 6321     Phillipston          Turkey    27.320519     400.992773
# 4500  Richardsonberg        Paraguay     9.290850     379.820127
# 3199  North Derekton    Saint Helena    14.194841     403.220230
#
#       Sea Level Rise  Precipitation   Humidity  Wind Speed  Year  Month  Day
# 2869       -0.639723      30.779914  99.959665   34.390077  2006      8    7
# 1953        1.173701      86.902713  99.955560    0.587979  2004      6   28
# ...

# %% [markdown]
# ##### least CO2 Emissions occured location

# %%
CO2_Emissions=data.nsmallest(1,'CO2 Emissions')

# %%
CO2_Emissions
# Out:
#          Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 9888  Jenniferton  Kuwait    14.278908      182.13122       -0.510499
#
#       Precipitation   Humidity  Wind Speed  Year  Month  Day
# 9888       87.96908  77.646321   49.649592  2022      9   28

# %% [markdown]
# ##### highest CO2 Emissions occured location

# %%
CO2_Emissions_high=data.nlargest(1,"CO2 Emissions")

# %%
CO2_Emissions_high
# Out:
#              Location       Country  Temperature  CO2 Emissions  \
# 442  Port Matthewfort  Burkina Faso      9.19869     582.899701
#
#      Sea Level Rise  Precipitation   Humidity  Wind Speed  Year  Month  Day
# 442       -2.408251      24.835655  68.317519   10.496046  2001      1    6

# %%
crss=pd.crosstab(data.Country,data.Year,data.Temperature,aggfunc='sum')

# %%
crss
# Out:
# Year                    2000       2001       2002       2003       2004  \
# Country
# Afghanistan        32.495836  27.435392   2.193931  49.673945  46.983613
# Albania            11.968125  41.655752  32.502228  20.715624  24.904760
# Algeria            40.245465  13.723152  25.468400  43.720834  35.587670
# American Samoa     26.985341  46.380649   7.490023  15.275581  42.192979
# Andorra            20.563356  31.169867   4.499491  75.120818  15.409821
# ...                      ...        ...        ...        ...        ...
# Wallis and Futuna  16.526264  44.876246  48.898890  16.059466  27.867187
# Western Sahara     43.913913  36.754077  49.386363  30.377745  31.365997
# Yemen              21.831419  13.653826  18.632904  39.523905        NaN
# Zambia                   NaN  31.646733  45.187000  35.629587        NaN
# Zimbabwe           71.567356  35.654582  24.876040        NaN  30.063965
#
# Year                    2005       2006       2007       2008       2009  ...  \
# ...

# %%
world_wide=data.query('Temperature>25 & Humidity>80')

# %%
world_wide
# Out:
#                  Location                                       Country  \
# 2        West Williamland                                 French Guiana
# 389         Gutierreztown                             Equatorial Guinea
# 527            Johnnyside                                         Kenya
# 877       East Meganshire                                       Bahrain
# 1145         Vanessaburgh                                    Guadeloupe
# 1195           Malonefort                                         China
# 1630          Parkerburgh                                        Greece
# 1718     North Staceytown                          United Arab Emirates
# 1856         Lake Jeffery                                       Mayotte
# 1995        Campbellshire                                       Georgia
# 2247          Martinshire                                      Slovenia
# 2675        Michellehaven                                       Moldova
# ...

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in world wide 2000 to 2020')
sns.lineplot(data=world_wide,x='Year',y='Temperature');
plt.show()

# %%
sns.regplot(data=world_wide,x='Temperature',y='CO2 Emissions')
plt.show()

# %% [markdown]
# ##### as per data set temperature increasing when CO2 emission increases and ,assuming it was like strong -ve correlation

# %% [markdown]
# ## country - INDIA analysis

# %%
india=data.query("Country=='India'")

# %%
india
# Out:
#                   Location Country  Temperature  CO2 Emissions  \
# 44             Stewartbury   India    13.863784     408.121863
# 153             Port Jesus   India    14.563792     441.458510
# 420           Lake Heather   India     8.050407     352.500027
# 604        Port Haydentown   India    12.435437     380.040060
# 626             Marisafort   India    19.580143     412.246774
# 754              Jacobland   India    18.290347     312.602899
# 764    South Kimberlyshire   India    12.013457     334.323596
# 1437             New David   India     8.794670     352.886364
# 2589      South Robertstad   India    18.649079     417.644878
# 2805            Bowersfurt   India    15.702748     462.738893
# 3217            Aliciaview   India    17.222168     342.906534
# 3403      North Laurieside   India    15.904627     354.901698
# 3548           Francisberg   India    19.211249     352.322940
# 3555             Masonfort   India    15.391247     449.799677
# ...

# %% [markdown]
# ##### least co2 emission in india

# %%
CO2_Emissions_India=india.nsmallest(1,'CO2 Emissions')

# %%
CO2_Emissions_India
# Out:
#        Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 7993  Davidbury   India      6.77018     285.499915        1.255241
#
#       Precipitation  Humidity  Wind Speed  Year  Month  Day
# 7993      32.294763  3.406655    3.137896  2018      5   20

# %% [markdown]
# ##### graph of Temperature in india 2000 to 2020

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in india 2000 to 2020')
sns.lineplot(data=india,x='Year',y='Temperature');
plt.show()

# %%
sns.regplot(data=india,x='Temperature',y='CO2 Emissions')
plt.show()

# %% [markdown]
# ###### as per data set temperature increasing when CO2 emission increases
# ##### weak positive correlation

# %%
sns.relplot(data=india,x='Year',y='Temperature',size='Humidity')
plt.show()

# %% [markdown]
# ##### from this data set in india humidity is high with respect to the increasing rate of temperature and from the year based analysis the correlation of both humidity and temperture are inctrasing

# %%
india.hist(figsize=(20,10),color='red');

# %%
plt.figure(figsize=(10,5))
plt.subplot(4,2,1)
sns.histplot(data=india,y='Temperature')

plt.subplot(4,2,2)
sns.histplot(data=india,y='CO2 Emissions')

plt.subplot(4,2,3)
sns.histplot(data=india,y='Sea Level Rise')

plt.subplot(4,2,4)
sns.histplot(data=india,y='Precipitation')

plt.subplot(4,2,5)
sns.histplot(data=india,y='Humidity')

plt.subplot(4,2,6)
sns.histplot(data=india,y='Wind Speed')

plt.subplot(4,2,7)
sns.histplot(data=india,y='Year')

plt.subplot(4,2,8)
sns.histplot(data=india,y='Month')


plt.show()

# %% [markdown]
# ##### from this data temperature is increasing while co2 emission and comparatively humidity increasing ,and the climate change  mostly occured in april to june  and october to december  ,and here seems sea leavel rising have a relation in humidity  that are propotional

# %% [markdown]
# ## temperature change in india each 5year intervel

# %% [markdown]
# ##### 2000 to 2005

# %%
ind_2000=india.query('Year<=2005')

# %%
ind_2000
# Out:
#                  Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 44            Stewartbury   India    13.863784     408.121863       -0.078811
# 153            Port Jesus   India    14.563792     441.458510        0.012392
# 420          Lake Heather   India     8.050407     352.500027       -1.081892
# 604       Port Haydentown   India    12.435437     380.040060       -0.376124
# 626            Marisafort   India    19.580143     412.246774        1.490122
# 754             Jacobland   India    18.290347     312.602899       -0.556386
# 764   South Kimberlyshire   India    12.013457     334.323596       -0.046268
# 1437            New David   India     8.794670     352.886364       -0.773098
# 2589     South Robertstad   India    18.649079     417.644878       -0.488305
#
#       Precipitation   Humidity  Wind Speed  Year  Month  Day
# 44        77.498661  31.356005   26.264121  2000      2    6
# 153       72.783893  64.897858   44.925654  2000      5    8
# ...

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in india 2000 to 2005')
sns.lineplot(data=ind_2000,x='Year',y='Temperature',color='purple');
plt.show()

# %% [markdown]
# ##### 2005 to 2010

# %%
ind_2005=india.query('Year>=2005 &Year<=2010')

# %%
ind_2005
# Out:
#               Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 2589  South Robertstad   India    18.649079     417.644878       -0.488305
# 2805        Bowersfurt   India    15.702748     462.738893       -1.027062
# 3217        Aliciaview   India    17.222168     342.906534       -0.509245
# 3403  North Laurieside   India    15.904627     354.901698        1.164165
# 3548       Francisberg   India    19.211249     352.322940       -0.808938
# 3555         Masonfort   India    15.391247     449.799677       -0.924855
# 4185  Lake Sandrashire   India    18.342157     415.020313        0.815616
# 4309        Oliverside   India    11.243023     397.590335       -0.095128
# 4358        Payneville   India    15.647535     418.629962        1.021754
#
#       Precipitation   Humidity  Wind Speed  Year  Month  Day
# 2589      74.032718  20.658963   43.859921  2005     12   14
# 2805      67.324433  39.692066   27.317580  2006      6   14
# ...

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in india 2005 to 2010')
sns.lineplot(data=ind_2005,x='Year',y='Temperature',color='orange');
plt.show()

# %% [markdown]
# #### 2010 to 2015

# %%
ind_2010=india.query('Year>=2010 &Year<=2015')

# %%
ind_2010
# Out:
#               Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 4358        Payneville   India    15.647535     418.629962        1.021754
# 5002        Keithmouth   India     6.834645     445.085225       -0.480513
# 5199        Philipstad   India    18.756186     393.825370       -1.813955
# 5377   Port Tonyamouth   India    13.819740     370.274955        0.018518
# 5443       South Jacob   India    13.756413     428.590540       -1.068654
# 5856        Lake James   India    12.507289     455.611153       -1.548433
# 5873        New Rachel   India    21.685629     486.868858        0.352379
# 5905  New Kathleenfurt   India    17.133907     431.969586        0.715348
# 5994          Evanport   India     7.514150     330.623113        0.010152
# 6079  West Williemouth   India    12.255525     455.327197        0.856938
# 6472     Jennifermouth   India    10.466862     357.520635        0.162902
#
#       Precipitation   Humidity  Wind Speed  Year  Month  Day
# ...

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in india 2010 to 2015')
sns.lineplot(data=ind_2010,x='Year',y='Temperature',color='green');
plt.show()

# %% [markdown]
# #### 2015 to 2020

# %%
ind_2015=india.query('Year>=2015 &Year<=2020')

# %%
ind_2015
# Out:
#               Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 6970  West Alyssaburgh   India    13.556874     397.459411        0.366069
# 7182       Williamfort   India    13.956852     388.803615       -0.954000
# 7261       Lake Daniel   India    12.381219     435.000744        0.661026
# 7993         Davidbury   India     6.770180     285.499915        1.255241
# 8139         Reneebury   India    16.018688     384.248765        0.294676
# 8151    East Christina   India    14.645818     504.731648       -0.292160
#
#       Precipitation   Humidity  Wind Speed  Year  Month  Day
# 6970      58.008503  41.125659   16.262198  2016      1   12
# 7182      88.713444  83.131379   17.328481  2016      7    8
# 7261      90.428662  36.548985   13.831111  2016      9   12
# 7993      32.294763   3.406655    3.137896  2018      5   20
# 8139      93.293706  72.501952    5.065935  2018      9   20
# 8151      69.741480  56.546109   25.096159  2018      9   30

# %%
plt.figure(figsize=(10,4))
plt.xlabel('year')
plt.ylabel('temperature')
plt.title('Temperature in india 2015 to 2020')
sns.lineplot(data=ind_2015,x='Year',y='Temperature',color='red');
plt.show()

# %% [markdown]
# ### line plot of indian temperature values   each 5 years

# %%
plt.figure(figsize=(10,5))
plt.subplot(3,2,1)
sns.lineplot(data=ind_2000,x='Temperature',y='Humidity',color='green')
plt.title('2000 to 2005')
plt.xticks(rotation=55)
#plt.subplot(4,2,2)
#sns.boxplot(data=ind_2000,y='Humidity')
#plt.title('2000 to 2005')

plt.subplot(3,2,2)
sns.lineplot(data=ind_2005,x='Temperature',y='Humidity',color='green')
plt.title('2005 to 2010')
plt.xticks(rotation=55)
#plt.subplot(4,2,4)
#sns.boxplot(data=ind_2005,y='Humidity')
#plt.title('2005 to 2010')


plt.subplot(3,2,5)
sns.lineplot(data=ind_2010,x='Temperature',y='Humidity',color='red')
plt.title('2010 to 2015')
plt.xticks(rotation=55)

#plt.subplot(4,2,6)
#sns.boxplot(data=ind_2010,y='Humidity')
#plt.title('2010 to 2015')


plt.subplot(3,2,6)
sns.lineplot(data=ind_2015,x='Temperature',y='Humidity',color='red')
plt.title('2015 to 2020')
plt.xticks(rotation=55)

#plt.subplot(4,2,8)
#sns.boxplot(data=ind_2015,y='Humidity')
#plt.title('2015 to 2020')

plt.show()

# %% [markdown]
# from the data set the temperature seems in the range of 09 to 20 range,
# the highest temperature measured in 2003 to 2005 years    (temperature range 19-20),
# and the rest of all years temperature variying range of 10 to 15,
# and in the year 2016 -2018 temperature seems constant range (range =13),
#
# in india temperature range varying with respect to the range of humidity ,
# from the results of line chart

# %%
plt.figure(figsize=(10,10))

heat_map=india.corr()
sns.heatmap(heat_map,vmin=-1,vmax=1,annot=True, linewidth=10)
plt.xticks(rotation=30)
plt.show()
